# %% [markdown]
# <a href="https://colab.research.google.com/github/KuldipDongare1707/Deep_Learning/blob/main/Word2Vec_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gensim
from gensim.models import Word2Vec,KeyedVectors

# %%
# !pip install wget

# %%
# !wget -c "https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz" ---Not Available
# Out:
# --2024-11-14 04:46:35--  https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 16.182.99.152, 16.15.193.129, 52.217.94.222, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|16.182.99.152|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2024-11-14 04:46:36 ERROR 404: Not Found.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("leadbest/googlenewsvectorsnegative300")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 3.17G/3.17G [00:41<00:00, 82.7MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/leadbest/googlenewsvectorsnegative300/versions/2

# %%
# Get the word2vec file path; assuming it's named "GoogleNews-vectors-negative300.bin"
# and is directly within the downloaded directory.
# Adjust this if the file name or location is different.
file_path = os.path.join(path, "GoogleNews-vectors-negative300.bin.gz")

# Load the model using the file path
model = KeyedVectors.load_word2vec_format(file_path, binary=True)

# %%
model['man'].shape
# Out:
# (300,)

# %%
model['man']
# Out:
# array([ 0.32617188,  0.13085938,  0.03466797, -0.08300781,  0.08984375,
#        -0.04125977, -0.19824219,  0.00689697,  0.14355469,  0.0019455 ,
#         0.02880859, -0.25      , -0.08398438, -0.15136719, -0.10205078,
#         0.04077148, -0.09765625,  0.05932617,  0.02978516, -0.10058594,
#        -0.13085938,  0.001297  ,  0.02612305, -0.27148438,  0.06396484,
#        -0.19140625, -0.078125  ,  0.25976562,  0.375     , -0.04541016,
#         0.16210938,  0.13671875, -0.06396484, -0.02062988, -0.09667969,
#         0.25390625,  0.24804688, -0.12695312,  0.07177734,  0.3203125 ,
#         0.03149414, -0.03857422,  0.21191406, -0.00811768,  0.22265625,
#        -0.13476562, -0.07617188,  0.01049805, -0.05175781,  0.03808594,
#        -0.13378906,  0.125     ,  0.0559082 , -0.18261719,  0.08154297,
#        -0.08447266, -0.07763672, -0.04345703,  0.08105469, -0.01092529,
#         0.17480469,  0.30664062, -0.04321289, -0.01416016,  0.09082031,
# ...

# %%
model.most_similar('man')
# Out:
# [('woman', 0.7664012908935547),
#  ('boy', 0.6824871301651001),
#  ('teenager', 0.6586930155754089),
#  ('teenage_girl', 0.6147903203964233),
#  ('girl', 0.5921714305877686),
#  ('suspected_purse_snatcher', 0.571636438369751),
#  ('robber', 0.5585119128227234),
#  ('Robbery_suspect', 0.5584409832954407),
#  ('teen_ager', 0.5549196600914001),
#  ('men', 0.5489763021469116)]

# %%
model.most_similar('google')
# Out:
# [('google.com', 0.6711485981941223),
#  ('google_yahoo', 0.6488178968429565),
#  ('wikipedia', 0.643608033657074),
#  ('www.google.com', 0.6258559226989746),
#  ('googled', 0.6166064143180847),
#  ('googling', 0.6086059212684631),
#  ('slashdot', 0.5964587330818176),
#  ('lifehacker', 0.5948858857154846),
#  ('gizmodo', 0.5884420275688171),
#  ('inurl', 0.5882638692855835)]

# %%
model.similarity('man','woman')
# Out:
# 0.76640123

# %%
model.similarity('man','JAVA')
# Out:
# -0.022547575

# %%
model.doesnt_match(['JAVA', 'Man', 'Monkey'])
# Out:
# 'JAVA'

# %%
vec = model['king'] - model['mann'] + model['woman']
model.most_similar([vec])
# Out:
# [('woman', 0.6337462067604065),
#  ('king', 0.5750621557235718),
#  ('man', 0.5466793775558472),
#  ('monarch', 0.5384223461151123),
#  ('queen', 0.5080338716506958),
#  ('teenage_girl', 0.5034098625183105),
#  ('girl', 0.4726634919643402),
#  ('prince', 0.470010906457901),
#  ('teenager', 0.46623143553733826),
#  ('crown_prince', 0.4503317177295685)]

# %% [markdown]
# ### GOT Example

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("jiya7316/game-of-thrones-books")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 3.64M/3.64M [00:00<00:00, 142MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/jiya7316/game-of-thrones-books/versions/1

# %%
import gensim
import os
import nltk

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

nltk.download('punkt_tab')

story = [ ]
for filename in os.listdir(path):
    f = open(os.path.join(path, filename))
    corpus = f.read()
    raw_sent = sent_tokenize(corpus)
    for sent in raw_sent:
      story.append(simple_preprocess(sent))
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
story[0]
# Out:
# ['feast',
#  'for',
#  'crows',
#  'bantam',
#  'spectra',
#  'book',
#  'november',
#  'published',
#  'by',
#  'bantam',
#  'dell',
#  'division',
#  'of',
#  'random',
#  'house',
#  'inc',
#  'new',
#  'york',
#  'new',
#  'york',
#  'this',
#  'is',
#  'work',
#  'of',
#  'fiction']

# %%
len(story)
# Out:
# 128869

# %%
model = gensim.models.Word2Vec(
    window=10,
    min_count=2,
    workers=4,
)

# %%
model.build_vocab(story)

# %%
model.train(story, total_examples = model.corpus_count, epochs = model.epochs)
# Out:
# (6583238, 8644930)

# %%
model.wv.most_similar('daenerys')
# Out:
# [('stormborn', 0.7664397358894348),
#  ('princess', 0.7060209512710571),
#  ('targaryen', 0.6803815960884094),
#  ('myrcella', 0.6549686789512634),
#  ('martell', 0.6516116261482239),
#  ('unburnt', 0.6365293264389038),
#  ('prince', 0.6325651407241821),
#  ('elia', 0.6215867400169373),
#  ('betrothed', 0.6163929104804993),
#  ('regent', 0.6159654855728149)]

# %%
model.wv.doesnt_match(['jon','rikon','robb','arya','sansa','bran'])
# Out:
# WARNING:gensim.models.keyedvectors:vectors for words {'rikon'} are not present in the model, ignoring these words
# 'jon'

# %%
model.wv['king']
# Out:
# array([ 0.55908567, -0.83491486,  0.9082572 ,  1.5900807 , -4.4707313 ,
#         0.7176509 ,  0.31218556,  0.3725867 , -2.6981974 , -0.97702545,
#        -0.6013704 , -2.0898988 ,  0.4272849 ,  2.2791479 , -2.677162  ,
#        -2.8500888 ,  0.7457189 , -0.05609101, -0.01694384, -1.1070136 ,
#         0.9525231 , -0.35834765,  1.6074129 , -2.4227886 , -2.5028265 ,
#        -0.13493352, -1.7369423 , -3.9591901 ,  1.4186459 ,  3.5007255 ,
#        -1.501718  ,  1.6612293 , -1.3427142 , -0.22738135, -1.4304054 ,
#        -3.2348268 , -2.92321   , -1.5549151 ,  0.56636465, -1.3152142 ,
#         0.33561578,  4.2678576 ,  3.7118363 , -0.6161307 , -0.47779745,
#        -0.36002383,  0.8639668 , -0.06585507,  3.2235248 , -1.9466445 ,
#        -2.2652605 , -0.53791875,  0.6243428 , -3.334026  ,  3.4576335 ,
#        -3.3464715 , -1.6900345 ,  2.209246  , -0.16772257,  1.263276  ,
#         0.5838321 , -1.1937842 ,  0.6302125 ,  0.2774752 ,  0.2621591 ,
# ...

# %%
model.wv.get_normed_vectors().shape
# Out:
# (17373, 100)

# %%
y = model.wv.index_to_key

# %%
y
# Out:
# ['the',
#  'and',
#  'to',
#  'of',
#  'he',
#  'his',
#  'was',
#  'you',
#  'her',
#  'in',
#  'it',
#  'had',
#  'that',
#  'she',
#  'as',
#  'with',
#  'him',
#  'not',
#  'but',
#  'for',
#  'they',
#  'is',
#  'at',
#  'on',
#  'said',
#  'my',
#  'have',
#  'be',
#  'lord',
#  'them',
#  'no',
#  'from',
#  'would',
#  'were',
#  'me',
#  'your',
#  'one',
#  'all',
#  'when',
#  'will',
#  'ser',
#  'if',
#  'so',
#  'their',
#  'we',
#  'could',
#  'are',
#  'man',
#  'there',
#  'this',
#  'up',
#  'been',
#  'what',
#  'by',
#  'did',
#  'king',
#  'do',
#  'men',
#  'back',
#  'out',
#  'more',
#  'or',
#  'who',
#  'down',
#  'well',
#  'than',
#  'only',
#  'jon',
#  'like',
#  'father',
#  'some',
#  'old',
#  'hand',
#  'tyrion',
#  'even',
#  'too',
#  'before',
#  'never',
#  'an',
#  'off',
#  'see',
#  'know',
#  'into',
#  'made',
#  'now',
#  'eyes',
#  'black',
#  'told',
#  'lady',
#  'thought',
#  'time',
#  'then',
#  'how',
#  'long',
#  'has',
#  'can',
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=100)

# %%
X = pca.fit_transform(model.wv.get_normed_vectors())

# %%
X[:5]
# Out:
# array([[-8.52670968e-02, -5.57315230e-01,  2.03846410e-01,
#         -1.43558621e-01, -1.32912993e-02, -1.86424553e-02,
#          2.46633962e-01,  4.94499058e-02,  1.12768665e-01,
#          1.56355545e-01, -7.58738536e-03, -2.03087807e-01,
#         -3.56174260e-02,  2.53759138e-02,  7.02757984e-02,
#          9.09114927e-02, -1.02497816e-01, -1.38058677e-01,
#          1.18349120e-01, -1.15050800e-01, -3.36202793e-02,
#          2.05944628e-01, -8.49010497e-02, -3.79870683e-01,
#         -8.23956206e-02, -7.50613138e-02,  4.49265428e-02,
#         -5.98004535e-02,  1.26319051e-01,  6.42916039e-02,
#         -8.01897943e-02, -1.82944939e-01, -6.89509362e-02,
#         -1.31704703e-01, -5.71320094e-02,  4.62524705e-02,
#         -7.87014887e-02,  1.90668516e-02, -4.62056603e-03,
#          6.85556158e-02, -6.95050210e-02, -1.26818523e-01,
#          2.06340998e-02, -1.69057071e-01,  4.69398759e-02,
#          1.33513466e-01,  6.56490251e-02, -8.62941816e-02,
# ...

# %%
X.shape
# Out:
# (17373, 100)

# %%
import plotly.express as px
fig = px.scatter_3d(X[:1000],x = 0, y = 1, z = 2, color = y[:1000])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
